# %%
import pandas as pd
df=pd.read_csv('dirty_cafe_sales.csv')
df.head()
df.tail()
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07

# %%
df.describe()
df.sample(10)
df.head(20)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 2     TXN_4271903    Cookie        4            1.0       ERROR
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 6     TXN_4433211   UNKNOWN        3            3.0         9.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 8     TXN_4717867       NaN        5            3.0        15.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 11    TXN_3051279  Sandwich        2            4.0         8.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# 14    TXN_8915701     ERROR        2            1.5         3.0
# 15    TXN_2847255     Salad        3            5.0        15.0
# 16    TXN_3765707  Sandwich        1            4.0         4.0
# 17    TXN_6769710     Juice        2            3.0         6.0
# 18    TXN_8876618      Cake        5            3.0        15.0
# 19    TXN_3709394     Juice        4            3.0        12.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3          UNKNOWN   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card       NaN       2023-03-31
# 6            ERROR  Takeaway       2023-10-06
# 7             Cash   UNKNOWN       2023-10-28
# 8              NaN  Takeaway       2023-07-28
# 9              NaN  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway            ERROR
# 12            Cash  In-store       2023-05-03
# 13             NaN  Takeaway       2023-06-01
# 14             NaN  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15
# 16             NaN       NaN       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash     ERROR       2023-03-25
# 19            Cash  Takeaway       2023-01-15

# %%
df['Item'].value_counts()
# Out:
# Item
# Juice       1171
# Coffee      1165
# Salad       1148
# Cake        1139
# Sandwich    1131
# Smoothie    1096
# Cookie      1092
# Tea         1089
# UNKNOWN      344
# ERROR        292
# Name: count, dtype: int64

# %%
df.isnull().sum()
df.duplicated().sum()
df.isnull()
df.tail(10)
df['Item'].replace(['UNKNOWN','ERROR'],pd.NA)
df['Item'].value_counts()
df['Item'] = df['Item'].ffill()
df['Item'].isnull().sum()
df['Item'].isnull().sum()
df.head()
#df['Price Per Unit'].astype('int')
df['Price Per Unit'] = df['Price Per Unit'].replace(['UNKNOWN','ERROR','nan'],pd.NA)
#df['Price Per Unit'].
df['Price Per Unit'].value_counts()
df['Price Per Unit'] = df['Price Per Unit'].ffill()
df['Price Per Unit'] = df['Price Per Unit'].astype(float).astype(int)

# %%
df.head()
df['Total Spent'].value_counts()
df['Total Spent'] = df['Total Spent'].astype(str)
df['Total Spent'] = df['Total Spent'].replace(['UNKNOWN','ERROR','nan'], pd.NA)
df['Total Spent'] = df['Total Spent'].fillna(4.0)
df['Total Spent'] = df['Total Spent'].replace('.','')
df['Total Spent'].value_counts()

df['Total Spent'] = df['Total Spent'].str.replace(r'(\d)\.(\d)', r'\1\2', regex=True)
df['Total Spent'] = df['Total Spent'].fillna(4.0)
#df['Total Spent'] = df['Total Spent'].astype(float)
df['Total Spent'] = df['Total Spent'].astype(int)
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee         2               2           40
# 1    TXN_4977031    Cake         4               3          120
# 2    TXN_4271903  Cookie         4               1            4
# 3    TXN_7034554   Salad         2               5          100
# 4    TXN_3160411  Coffee         2               2           40
#
#    Payment Method  Location Transaction Date      month       days
# 0     Credit Card  Takeaway       2023-09-08  September     Friday
# 1            Cash  In-store       2023-05-16        May    Tuesday
# 2     Credit Card  In-store       2023-07-19       July  Wednesday
# 3     Credit Card  In-store       2023-04-27      April   Thursday
# 4  Digital Wallet  In-store       2023-06-11       June     Sunday

# %%
df['Quantity'].value_counts()
df['Quantity'] = df['Quantity'].replace(['UNKNOWN','ERROR'],pd.NA)
df['Quantity'].value_counts()
df['Quantity'] = df['Quantity'].ffill()
df['Quantity'] = df['Quantity'].astype(int)

df['Payment Method'] = df['Payment Method'].replace(['UNKNOWN','ERROR'],pd.NA)
df['Payment Method'] = df['Payment Method'].ffill()
df['Payment Method'].value_counts()

df.head()
df['Location'] = df['Location'].replace(['UNKNOWN','ERROR','nan'],pd.NA)
df['Location'].unique()
df['Location'] = df['Location'].ffill()
df['Location'].isnull().sum()
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee         2               2           40
# 1    TXN_4977031    Cake         4               3          120
# 2    TXN_4271903  Cookie         4               1            4
# 3    TXN_7034554   Salad         2               5          100
# 4    TXN_3160411  Coffee         2               2           40
#
#    Payment Method  Location Transaction Date      month       days
# 0     Credit Card  Takeaway       2023-09-08  September     Friday
# 1            Cash  In-store       2023-05-16        May    Tuesday
# 2     Credit Card  In-store       2023-07-19       July  Wednesday
# 3     Credit Card  In-store       2023-04-27      April   Thursday
# 4  Digital Wallet  In-store       2023-06-11       June     Sunday

# %%
df['Transaction Date'].value_counts()
#df['Transaction Date'].isnull().sum()
df['Transaction Date'] = df['Transaction Date'].replace(['UNKNOWN','ERROR'],pd.NA)
df['Transaction Date'] = df['Transaction Date'].ffill()
df['Transaction Date'].isnull().sum()
df['Transaction Date'] = df['Transaction Date'].astype(str)
df['Transaction Date'].dtype
#df['Transaction date'].dt.month
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])
df['Transaction Date'].dtype
df['month'] = df['Transaction Date'].dt.month_name()
df['days'] = df['Transaction Date'].dt.day_name()
df1 = df.groupby('month')['Total Spent'].sum()
df2 = df.groupby('days')['Total Spent'].sum()
df1.plot(x= 'month', y='Total Spent', kind = 'bar')
df2.plot(x= 'days', y= 'Total Spent' , kind='bar')
# Out:
# <Axes: xlabel='days'>

# %%
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee         2               2           40
# 1    TXN_4977031    Cake         4               3          120
# 2    TXN_4271903  Cookie         4               1            4
# 3    TXN_7034554   Salad         2               5          100
# 4    TXN_3160411  Coffee         2               2           40
#
#    Payment Method  Location Transaction Date      month       days
# 0     Credit Card  Takeaway       2023-09-08  September     Friday
# 1            Cash  In-store       2023-05-16        May    Tuesday
# 2     Credit Card  In-store       2023-07-19       July  Wednesday
# 3     Credit Card  In-store       2023-04-27      April   Thursday
# 4  Digital Wallet  In-store       2023-06-11       June     Sunday

# %% [markdown]
#  to insert a column
#  df.insert(2,'total',df['price']*['quantity'])

# %%
import plotly.express as px

# %%
df.head() 
df['Transaction Date']
# Out:
# 0      2023-09-08
# 1      2023-05-16
# 2      2023-07-19
# 3      2023-04-27
# 4      2023-06-11
#           ...
# 9995   2023-08-30
# 9996   2023-06-02
# 9997   2023-03-02
# 9998   2023-12-02
# 9999   2023-11-07
# Name: Transaction Date, Length: 10000, dtype: datetime64[ns]

# %%
df['Transaction Date'] = df['Transaction Date'].astype(str)
df['Transaction Date'].dtype
df['Transaction Date'].apply(lambda x: x.split('-')[0].strip('3'))
# Out:
# 0       202
# 1       202
# 2       202
# 3       202
# 4       202
#        ...
# 9995    202
# 9996    202
# 9997    202
# 9998    202
# 9999    202
# Name: Transaction Date, Length: 10000, dtype: object

# %%
df.head()
s= df.groupby(by='Item')
for i in s:
    print(i)
# Out:
# ('Cake',      Transaction ID  Item  Quantity  Price Per Unit  Total Spent  \
# 1       TXN_4977031  Cake         4               3          120
# 18      TXN_8876618  Cake         5               3          150
# 29      TXN_7640952  Cake         4               3          120
# 30      TXN_1736287  Cake         5               2          100
# 49      TXN_8230936  Cake         3               3           90
# ...             ...   ...       ...             ...          ...
# 9964    TXN_8938445  Cake         3               3           90
# 9972    TXN_3124078  Cake         4               3          120
# 9975    TXN_9668108  Cake         1               3           30
# 9985    TXN_3297457  Cake         2               3           60
# 9988    TXN_9594133  Cake         5               3            4
#
#       Payment Method  Location Transaction Date     month      days
# 1               Cash  In-store       2023-05-16       May   Tuesday
# 18              Cash  In-store       2023-03-25     March  Saturday
# 29    Digital Wallet  Takeaway       2023-03-11     March  Saturday
# 30    Digital Wallet  Takeaway       2023-06-02      June    Friday
# 49              Cash  In-store       2023-05-02       May   Tuesday
# ...              ...       ...              ...       ...       ...
# 9964            Cash  In-store       2023-11-07  November   Tuesday
# 9972            Cash  In-store       2023-08-06    August    Sunday
# 9975            Cash  In-store       2023-01-20   January    Friday
# 9985            Cash  Takeaway       2023-01-03   January   Tuesday
# 9988            Cash  In-store       2023-07-31      July    Monday
#
# [1176 rows x 10 columns])
# ('Coffee',      Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373  Coffee         2               2           40
# 4       TXN_3160411  Coffee         2               2           40
# 39      TXN_6688524  Coffee         4               2           80
# 75      TXN_6420335  Coffee         1               2           20
# 80      TXN_3748616  Coffee         2               2           40
# ...             ...     ...       ...             ...          ...
# 9969    TXN_9954652  Coffee         2               2           40
# 9990    TXN_1538510  Coffee         5               2          100
# 9995    TXN_7672686  Coffee         2               2           40
# 9996    TXN_9659401  Coffee         3               2           30
# 9997    TXN_5255387  Coffee         4               2           80
#
#       Payment Method  Location Transaction Date      month       days
# 0        Credit Card  Takeaway       2023-09-08  September     Friday
# 4     Digital Wallet  In-store       2023-06-11       June     Sunday
# 39       Credit Card  Takeaway       2023-06-29       June   Thursday
# 75              Cash  Takeaway       2023-07-16       July     Sunday
# 80       Credit Card  In-store       2023-12-09   December   Saturday
# ...              ...       ...              ...        ...        ...
# 9969            Cash  In-store       2023-09-12  September    Tuesday
# 9990  Digital Wallet  In-store       2023-05-22        May     Monday
# 9995            Cash  In-store       2023-08-30     August  Wednesday
# 9996  Digital Wallet  In-store       2023-06-02       June     Friday
# 9997  Digital Wallet  In-store       2023-03-02      March   Thursday
#
# [1204 rows x 10 columns])
# ('Cookie',      Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 2       TXN_4271903  Cookie         4               1            4
# 13      TXN_9437049  Cookie         5               1           50
# 26      TXN_5183041  Cookie         5               1           50
# 44      TXN_1491578  Cookie         2               1           20
# 55      TXN_5522862  Cookie         5               1           20
# ...             ...     ...       ...             ...          ...
# 9945    TXN_8153550  Cookie         2               1           20
# 9956    TXN_1958525  Cookie         3               1           30
# 9976    TXN_3528020  Cookie         1               1           10
# 9982    TXN_8567525  Cookie         2               1           20
# 9998    TXN_7695629  Cookie         3               2           30
#
#       Payment Method  Location Transaction Date     month       days
# 2        Credit Card  In-store       2023-07-19      July  Wednesday
# 13              Cash  Takeaway       2023-06-01      June   Thursday
# 26       Credit Card  In-store       2023-04-20     April   Thursday
# 44       Credit Card  Takeaway       2023-02-23  February   Thursday
# 55       Credit Card  Takeaway       2023-03-19     March     Sunday
# ...              ...       ...              ...       ...        ...
# 9945            Cash  Takeaway       2023-10-12   October   Thursday
# 9956     Credit Card  Takeaway       2023-10-08   October     Sunday
# 9976            Cash  Takeaway       2023-08-26    August   Saturday
# 9982  Digital Wallet  Takeaway       2023-12-30  December   Saturday
# 9998  Digital Wallet  In-store       2023-12-02  December   Saturday
#
# [1130 rows x 10 columns])
# ('ERROR',      Transaction ID   Item  Quantity  Price Per Unit  Total Spent  \
# 14      TXN_8915701  ERROR         2               1           30
# 69      TXN_8471743  ERROR         5               3          150
# 88      TXN_9487821  ERROR         1               5           50
# 89      TXN_4132730  ERROR         5               1           50
# 118     TXN_4633784  ERROR         5               3          150
# ...             ...    ...       ...             ...          ...
# 9910    TXN_2338617  ERROR         2               3           60
# 9918    TXN_2292088  ERROR         1               4           40
# 9951    TXN_4122925  ERROR         4               1           40
# 9958    TXN_4125474  ERROR         2               5          100
# 9981    TXN_4583012  ERROR         5               4          200
#
#       Payment Method  Location Transaction Date     month       days
# 14              Cash  In-store       2023-03-21     March    Tuesday
# 69    Digital Wallet  In-store       2023-04-06     April   Thursday
# 88    Digital Wallet  Takeaway       2023-05-24       May  Wednesday
# 89    Digital Wallet  In-store       2023-03-12     March     Sunday
# 118   Digital Wallet  In-store       2023-02-06  February     Monday
# ...              ...       ...              ...       ...        ...
# 9910  Digital Wallet  Takeaway       2023-01-12   January   Thursday
# 9918  Digital Wallet  Takeaway       2023-03-04     March   Saturday
# 9951  Digital Wallet  Takeaway       2023-10-20   October     Friday
# 9958     Credit Card  In-store       2023-08-02    August  Wednesday
# 9981  Digital Wallet  In-store       2023-02-27  February     Monday
#
# [301 rows x 10 columns])
# ('Juice',      Transaction ID   Item  Quantity  Price Per Unit  Total Spent  \
# 17      TXN_6769710  Juice         2               3           60
# 19      TXN_3709394  Juice         4               3          120
# 27      TXN_5695074  Juice         4               3          120
# 43      TXN_9620080  Juice         4               3          120
# 46      TXN_8078640  Juice         4               3          120
# ...             ...    ...       ...             ...          ...
# 9960    TXN_3546629  Juice         5               3          150
# 9967    TXN_8563793  Juice         4               3          120
# 9977    TXN_5548914  Juice         2               3            4
# 9987    TXN_1784478  Juice         5               3          150
# 9989    TXN_1741685  Juice         5               3          150
#
#       Payment Method  Location Transaction Date     month      days
# 17              Cash  In-store       2023-02-24  February    Friday
# 19              Cash  Takeaway       2023-01-15   January    Sunday
# 27       Credit Card  Takeaway       2023-04-10     April    Monday
# 43       Credit Card  Takeaway       2023-10-02   October    Monday
# 46    Digital Wallet  In-store       2023-11-03  November    Friday
# ...              ...       ...              ...       ...       ...
# 9960  Digital Wallet  In-store       2023-03-04     March  Saturday
# 9967  Digital Wallet  In-store       2023-03-26     March    Sunday
# 9977  Digital Wallet  In-store       2023-11-04  November  Saturday
# 9987            Cash  In-store       2023-07-31      July    Monday
# 9989            Cash  In-store       2023-08-18    August    Friday
#
# [1215 rows x 10 columns])
# ('Salad',      Transaction ID   Item  Quantity  Price Per Unit  Total Spent  \
# 3       TXN_7034554  Salad         2               5          100
# 10      TXN_2548360  Salad         5               5          250
# 15      TXN_2847255  Salad         3               5          150
# 37      TXN_1080432  Salad         2               5          100
# 45      TXN_5455792  Salad         3               5          150
# ...             ...    ...       ...             ...          ...
# 9928    TXN_5171519  Salad         3               5          150
# 9940    TXN_8273780  Salad         2               5          100
# 9942    TXN_5344848  Salad         1               5           50
# 9971    TXN_6120851  Salad         5               5          250
# 9973    TXN_7936002  Salad         2               5          100
#
#       Payment Method  Location Transaction Date      month       days
# 3        Credit Card  In-store       2023-04-27      April   Thursday
# 10              Cash  Takeaway       2023-11-07   November    Tuesday
# 15       Credit Card  In-store       2023-11-15   November  Wednesday
# 37       Credit Card  In-store       2023-04-29      April   Saturday
# 45              Cash  Takeaway       2023-03-22      March  Wednesday
# ...              ...       ...              ...        ...        ...
# 9928  Digital Wallet  In-store       2023-04-06      April   Thursday
# 9940  Digital Wallet  Takeaway       2023-10-15    October     Sunday
# 9942  Digital Wallet  Takeaway       2023-09-27  September  Wednesday
# 9971            Cash  Takeaway       2023-02-04   February   Saturday
# 9973  Digital Wallet  In-store       2023-01-26    January   Thursday
#
# [1179 rows x 10 columns])
# ('Sandwich',      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 7       TXN_6699534  Sandwich         4               4          160
# 8       TXN_4717867  Sandwich         5               3          150
# 9       TXN_2064365  Sandwich         5               4          200
# 11      TXN_3051279  Sandwich         2               4           80
# 12      TXN_7619095  Sandwich         2               4           80
# ...             ...       ...       ...             ...          ...
# 9962    TXN_4723089  Sandwich         4               4          160
# 9970    TXN_5762440  Sandwich         5               4          200
# 9986    TXN_2858441  Sandwich         2               4           80
# 9991    TXN_3897619  Sandwich         3               4          120
# 9999    TXN_6170729  Sandwich         3               4          120
#
#      Payment Method  Location Transaction Date     month       days
# 7              Cash  Takeaway       2023-10-28   October   Saturday
# 8              Cash  Takeaway       2023-07-28      July     Friday
# 9              Cash  In-store       2023-12-31  December     Sunday
# 11      Credit Card  Takeaway       2023-11-07  November    Tuesday
# 12             Cash  In-store       2023-05-03       May  Wednesday
# ...             ...       ...              ...       ...        ...
# 9962           Cash  In-store       2023-05-23       May    Tuesday
# 9970           Cash  In-store       2023-03-05     March     Sunday
# 9986    Credit Card  In-store       2023-12-14  December   Thursday
# 9991           Cash  Takeaway       2023-02-24  February     Friday
# 9999           Cash  In-store       2023-11-07  November    Tuesday
#
# [1168 rows x 10 columns])
# ('Smoothie',      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 5       TXN_2602893  Smoothie         5               4          200
# 20      TXN_3522028  Smoothie         4               4          200
# 21      TXN_3567645  Smoothie         4               4          160
# 25      TXN_7958992  Smoothie         3               4            4
# 28      TXN_8467949  Smoothie         5               4          200
# ...             ...       ...       ...             ...          ...
# 9979    TXN_9933628  Smoothie         5               4          200
# 9983    TXN_9226047  Smoothie         3               4          120
# 9984    TXN_3142496  Smoothie         3               4           40
# 9992    TXN_2739140  Smoothie         4               4          160
# 9993    TXN_4766549  Smoothie         2               4            4
#
#      Payment Method  Location Transaction Date     month       days
# 5       Credit Card  In-store       2023-03-31     March     Friday
# 20             Cash  In-store       2023-04-04     April    Tuesday
# 21      Credit Card  Takeaway       2023-03-30     March   Thursday
# 25             Cash  In-store       2023-12-13  December  Wednesday
# 28      Credit Card  Takeaway       2023-03-11     March   Saturday
# ...             ...       ...              ...       ...        ...
# 9979           Cash  In-store       2023-07-20      July   Thursday
# 9983           Cash  Takeaway       2023-12-30  December   Saturday
# 9984           Cash  Takeaway       2023-07-27      July   Thursday
# 9992           Cash  In-store       2023-07-05      July  Wednesday
# 9993           Cash  In-store       2023-10-20   October     Friday
#
# [1139 rows x 10 columns])
# ('Tea',      Transaction ID Item  Quantity  Price Per Unit  Total Spent  \
# 42      TXN_6650263  Tea         2               1            4
# 70      TXN_2621580  Tea         2               1           30
# 78      TXN_8735480  Tea         5               1           75
# 85      TXN_8035512  Tea         3               3           45
# 90      TXN_8976658  Tea         2               1           30
# ...             ...  ...       ...             ...          ...
# 9961    TXN_2153100  Tea         2               3           30
# 9965    TXN_5846013  Tea         2               1           30
# 9974    TXN_8076061  Tea         4               1           60
# 9978    TXN_4302199  Tea         3               1           45
# 9980    TXN_6796890  Tea         4               1           60
#
#       Payment Method  Location Transaction Date     month       days
# 42       Credit Card  Takeaway       2023-01-10   January    Tuesday
# 70              Cash  In-store       2023-03-22     March  Wednesday
# 78              Cash  In-store       2023-06-02      June     Friday
# 85              Cash  In-store       2023-10-29   October     Sunday
# 90       Credit Card  In-store       2023-08-16    August  Wednesday
# ...              ...       ...              ...       ...        ...
# 9961            Cash  In-store       2023-12-29  December     Friday
# 9965  Digital Wallet  In-store       2023-12-20  December  Wednesday
# 9974            Cash  In-store       2023-04-01     April   Saturday
# 9978  Digital Wallet  In-store       2023-02-16  February   Thursday
# 9980            Cash  In-store       2023-08-24    August   Thursday
#
# [1130 rows x 10 columns])
# ('UNKNOWN',      Transaction ID     Item  Quantity  Price Per Unit  Total Spent  \
# 6       TXN_4433211  UNKNOWN         3               3           90
# 31      TXN_8927252  UNKNOWN         2               1            4
# 33      TXN_7710508  UNKNOWN         5               1           50
# 36      TXN_6855453  UNKNOWN         4               3          120
# 52      TXN_8914892  UNKNOWN         5               5          250
# ...             ...      ...       ...             ...          ...
# 9764    TXN_1688292  UNKNOWN         3               3           90
# 9777    TXN_4385826  UNKNOWN         2               1           30
# 9836    TXN_9162296  UNKNOWN         3               4          120
# 9946    TXN_8807600  UNKNOWN         1               4           40
# 9994    TXN_7851634  UNKNOWN         4               4          160
#
#       Payment Method  Location Transaction Date      month       days
# 6        Credit Card  Takeaway       2023-10-06    October     Friday
# 31       Credit Card  Takeaway       2023-11-06   November     Monday
# 33              Cash  In-store       2023-08-15     August    Tuesday
# 36       Credit Card  In-store       2023-07-17       July     Monday
# 52    Digital Wallet  Takeaway       2023-03-15      March  Wednesday
# ...              ...       ...              ...        ...        ...
# 9764     Credit Card  In-store       2023-08-15     August    Tuesday
# 9777     Credit Card  Takeaway       2023-08-02     August  Wednesday
# 9836            Cash  In-store       2023-05-10        May  Wednesday
# 9946            Cash  Takeaway       2023-09-24  September     Sunday
# 9994            Cash  In-store       2023-01-08    January     Sunday
#
# [358 rows x 10 columns])

# %%
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee         2               2           40
# 1    TXN_4977031    Cake         4               3          120
# 2    TXN_4271903  Cookie         4               1            4
# 3    TXN_7034554   Salad         2               5          100
# 4    TXN_3160411  Coffee         2               2           40
#
#    Payment Method  Location Transaction Date      month       days
# 0     Credit Card  Takeaway       2023-09-08  September     Friday
# 1            Cash  In-store       2023-05-16        May    Tuesday
# 2     Credit Card  In-store       2023-07-19       July  Wednesday
# 3     Credit Card  In-store       2023-04-27      April   Thursday
# 4  Digital Wallet  In-store       2023-06-11       June     Sunday

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df.iat[2,'Items']
#
# File c:\Users\abc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:2526, in _ScalarAccessIndexer.__getitem__(self, key)
#    2523     else:
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
# -> 2526 key = self._convert_key(key)
#    2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File c:\Users\abc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:2599, in _iAtIndexer._convert_key(self, key)
#    2597 for i in key:
#    2598     if not is_integer(i):
# -> 2599         raise ValueError("iAt based indexing can only have integer indexers")
#    2600 return key
#
# ValueError: iAt based indexing can only have integer indexers
